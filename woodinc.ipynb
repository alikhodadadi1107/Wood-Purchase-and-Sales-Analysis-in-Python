# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # reading , clean data , rename columns

# %%
purchase = pd. read_excel('WoodInc-purchase.xlsx')
purchase.head(10)
# Out:
#       تاريخ  شماره  کد تأمین کننده  \
# 0  13990117      1         1100251
# 1  13990117      1         1100251
# 2  13990117      1         1100251
# 3  13990117      1         1100251
# 4  13990119      2         1100249
# 5  13990119      2         1100249
# 6  13990119      2         1100249
# 7  13990119      2         1100249
# 8  13990119      2         1100249
# 9  13990119      2         1100249
#
#                                      نام تأمین کننده               کد کالا  \
# 0  شركت تخته فشرده شمال                          ...  1-1-04-015
# 1  شركت تخته فشرده شمال                          ...  1-1-04-022
# 2  شركت تخته فشرده شمال                          ...  1-1-02-003
# 3  شركت تخته فشرده شمال                          ...  1-1-02-009
# 4  شركت پالار                                    ...  1-1-04-131
# 5  شركت پالار                                    ...  1-1-04-198
# 6  شركت پالار                                    ...  1-1-04-177
# ...

# %%
purchase.columns
# Out:
# Index(['تاريخ', 'شماره', 'کد تأمین کننده', 'نام تأمین کننده', 'کد کالا',
#        'نام کالا', 'واحد', 'مقدار', 'في', 'مبلغ', 'ماليات', 'تخفيف', 'عوارض',
#        'مبلغ خالص', 'تاريخ تسويه', 'سريال انبار'],
#       dtype='object')

# %%
purchase.columns = [ 'date' , 'ID' , 'Vendor_code','Vendor_Name' , 'Item_Code' , 'Description' , 'Unit' , 'Quantity','Unit Price' , 'Amount' , 'Tax' ,'Discount',
                    'Duties' , 'Net Amount' , 'Payment Date' , 'Warehouse Serial' ] 

purchase.head()
# Out:
#        date  ID  Vendor_code  \
# 0  13990117   1      1100251
# 1  13990117   1      1100251
# 2  13990117   1      1100251
# 3  13990117   1      1100251
# 4  13990119   2      1100249
#
#                                          Vendor_Name             Item_Code  \
# 0  شركت تخته فشرده شمال                          ...  1-1-04-015
# 1  شركت تخته فشرده شمال                          ...  1-1-04-022
# 2  شركت تخته فشرده شمال                          ...  1-1-02-003
# 3  شركت تخته فشرده شمال                          ...  1-1-02-009
# 4  شركت پالار                                    ...  1-1-04-131
#
#                                          Description  \
# 0  ملامينه 204*260 كد 1 سفيد درجه A              ...
# 1  ملامينه 204*260 كد 78 آنتيك لايت درجه A       ...
# 2  زيرپالتي نئوپان 204*260                       ...
# 3  زيرپالتي ام دي اف 3ميل                        ...
# 4  ملامينه 210*366 كد 1 سفيد درجه A              ...
#
# ...

# %%
purchase.replace(["NaN", "None", "null", "", " "], np.nan, inplace=True)

# %%
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232 entries, 0 to 2231
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              2232 non-null   int64
#  1   ID                2232 non-null   int64
#  2   Vendor_code       2232 non-null   int64
#  3   Vendor_Name       2232 non-null   object
#  4   Item_Code         2232 non-null   object
#  5   Description       2232 non-null   object
#  6   Unit              2232 non-null   object
#  7   Quantity          2232 non-null   float64
#  8   Unit Price        2232 non-null   int64
#  9   Amount            2232 non-null   int64
#  10  Tax               2232 non-null   int64
#  11  Discount          2232 non-null   int64
#  12  Duties            2232 non-null   int64
#  13  Net Amount        2232 non-null   int64
#  14  Payment Date      2232 non-null   object
#  15  Warehouse Serial  2232 non-null   int64
# ...

# %%
purchase.isnull().sum(axis = 0)
# Out:
# date                0
# ID                  0
# Vendor_code         0
# Vendor_Name         0
# Item_Code           0
# Description         0
# Unit                0
# Quantity            0
# Unit Price          0
# Amount              0
# Tax                 0
# Discount            0
# Duties              0
# Net Amount          0
# Payment Date        0
# Warehouse Serial    0
# dtype: int64

# %%
purchase.isnull().sum().sum()
# Out:
# 0

# %%
purchase.duplicated(keep=False).sum()
# Out:
# 22

# %%
dups        = purchase.duplicated(keep = False) 
dups_purchase = purchase.loc[dups]
dups_purchase
# Out:
#           date   ID  Vendor_code  \
# 249   13990317   64      1101747
# 250   13990317   64      1101747
# 352   13990326   85      1101124
# 353   13990326   85      1101124
# 356   13990326   85      1101124
# 357   13990326   85      1101124
# 833   13990515  167      1100127
# 836   13990515  167      1100127
# 1260  13990719  267      1101747
# 1261  13990719  267      1101747
# 1416  13990819  307      1100251
# 1417  13990819  307      1100251
# 1621  13990909  336      1100252
# 1622  13990909  336      1100252
# 1623  13990909  336      1100252
# 1624  13990909  336      1100252
# 1816  13991010  381      1101124
# 1817  13991010  381      1101124
# 1910  13991025  406      1100250
# 1912  13991025  406      1100250
# 2104  13991209  462      1102155
# 2105  13991209  462      1102155
#
#                                             Vendor_Name             Item_Code  \
# 249   شركت آرين تخته                                ...  1-1-02-032
# ...

# %%
purchase.drop_duplicates(inplace=True)

# %%
purchase[['Amount' , 'Tax' , 'Discount'	, 'Duties' ,	'Net Amount' ]] = purchase [ ['Amount' , 'Tax' , 'Discount'	, 'Duties' ,	'Net Amount' ]].abs()

# %%
purchase.columns
# Out:
# Index(['date', 'ID', 'Vendor_code', 'Vendor_Name', 'Item_Code', 'Description',
#        'Unit', 'Quantity', 'Unit Price', 'Amount', 'Tax', 'Discount', 'Duties',
#        'Net Amount', 'Payment Date', 'Warehouse Serial'],
#       dtype='object')

# %%
purchase.nunique()
# Out:
# date                211
# ID                  500
# Vendor_code          26
# Vendor_Name          26
# Item_Code           556
# Description         556
# Unit                  5
# Quantity            176
# Unit Price          315
# Amount              771
# Tax                 714
# Discount             55
# Duties                1
# Net Amount          754
# Payment Date          1
# Warehouse Serial    510
# dtype: int64

# %%
purchase.groupby(by='Vendor_Name').nunique()
# Out:
#                                                     date   ID  Vendor_code  \
# Vendor_Name
# اتحاديه سراسري درودگران                        ...     2    2            1
# خوش چسب كرمان                                  ...     7    7            1
# زاگرس چوب سام                                  ...    11   11            1
# سندل چوب                                       ...    12   12            1
# شركت آرين تخته                                 ...     7    7            1
# شركت آرين سينا                                 ...     3    3            1
# شركت آرين شيمي                                 ...     1    1            1
# شركت آرين مريم                                 ...     4    4            1
# شركت احسان كار اصفهان                          ...     4    4            1
# شركت افرا چوب                                  ...     2    2            1
# شركت تخته فشرده آريانا(پانيذ)                  ...     2    2            1
# ...

# %%
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2221 entries, 0 to 2231
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              2221 non-null   int64
#  1   ID                2221 non-null   int64
#  2   Vendor_code       2221 non-null   int64
#  3   Vendor_Name       2221 non-null   object
#  4   Item_Code         2221 non-null   object
#  5   Description       2221 non-null   object
#  6   Unit              2221 non-null   object
#  7   Quantity          2221 non-null   float64
#  8   Unit Price        2221 non-null   int64
#  9   Amount            2221 non-null   int64
#  10  Tax               2221 non-null   int64
#  11  Discount          2221 non-null   int64
#  12  Duties            2221 non-null   int64
#  13  Net Amount        2221 non-null   int64
#  14  Payment Date      2221 non-null   object
#  15  Warehouse Serial  2221 non-null   int64
# ...

# %%
#purchase.date   = pd.to_datetime(purchase.date)

# %%
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2221 entries, 0 to 2231
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              2221 non-null   int64
#  1   ID                2221 non-null   int64
#  2   Vendor_code       2221 non-null   int64
#  3   Vendor_Name       2221 non-null   object
#  4   Item_Code         2221 non-null   object
#  5   Description       2221 non-null   object
#  6   Unit              2221 non-null   object
#  7   Quantity          2221 non-null   float64
#  8   Unit Price        2221 non-null   int64
#  9   Amount            2221 non-null   int64
#  10  Tax               2221 non-null   int64
#  11  Discount          2221 non-null   int64
#  12  Duties            2221 non-null   int64
#  13  Net Amount        2221 non-null   int64
#  14  Payment Date      2221 non-null   object
#  15  Warehouse Serial  2221 non-null   int64
# ...

# %%
#purchase['Vendor_Name'] = purchase['Vendor_Name'].str.strip()
purchase.Vendor_Name.str.strip()
# Out:
# 0       شركت تخته فشرده شمال
# 1       شركت تخته فشرده شمال
# 2       شركت تخته فشرده شمال
# 3       شركت تخته فشرده شمال
# 4                 شركت پالار
#                 ...
# 2227           شركت راش بينه
# 2228           شركت راش بينه
# 2229           شركت راش بينه
# 2230           شركت راش بينه
# 2231           شركت راش بينه
# Name: Vendor_Name, Length: 2221, dtype: object

# %%
purchase.head()
# Out:
#        date  ID  Vendor_code  \
# 0  13990117   1      1100251
# 1  13990117   1      1100251
# 2  13990117   1      1100251
# 3  13990117   1      1100251
# 4  13990119   2      1100249
#
#                                          Vendor_Name             Item_Code  \
# 0  شركت تخته فشرده شمال                          ...  1-1-04-015
# 1  شركت تخته فشرده شمال                          ...  1-1-04-022
# 2  شركت تخته فشرده شمال                          ...  1-1-02-003
# 3  شركت تخته فشرده شمال                          ...  1-1-02-009
# 4  شركت پالار                                    ...  1-1-04-131
#
#                                          Description  \
# 0  ملامينه 204*260 كد 1 سفيد درجه A              ...
# 1  ملامينه 204*260 كد 78 آنتيك لايت درجه A       ...
# 2  زيرپالتي نئوپان 204*260                       ...
# 3  زيرپالتي ام دي اف 3ميل                        ...
# 4  ملامينه 210*366 كد 1 سفيد درجه A              ...
#
# ...

# %% [markdown]
# # جمع کل فروش هر تامین کننده

# %%
vendor_sales = purchase.groupby('Vendor_Name')['Net Amount'].sum().reset_index()
vendor_sales.head(10)
# Out:
#                                          Vendor_Name   Net Amount
# 0  اتحاديه سراسري درودگران                       ...   1869692861
# 1  خوش چسب كرمان                                 ...   4639974391
# 2  زاگرس چوب سام                                 ...  15731928319
# 3  سندل چوب                                      ...  17629202086
# 4  شركت آرين تخته                                ...   9255260369
# 5  شركت آرين سينا                                ...   3965751360
# 6  شركت آرين شيمي                                ...   1739208779
# 7  شركت آرين مريم                                ...   4499053480
# 8  شركت احسان كار اصفهان                         ...   5113000739
# 9  شركت افرا چوب                                 ...   6100387332

# %% [markdown]
# ## ترتیب سه تامین کننده برا اساس میزان فروش

# %%
# ترتیب سه تامین کننده برا اساس میزان فروش  


top_vendors = vendor_sales.sort_values(ascending= False , by = 'Net Amount')

top_vendors.reset_index()
# Out:
#     index                                        Vendor_Name    Net Amount
# 0      14  شركت راش بينه                                 ...  188564083823
# 1      20  شركت پالار                                    ...  173842152375
# 2      11  شركت تخته فشرده شمال                          ...  103193429390
# 3      15  شركت روكش آريا پويا                           ...   36595766438
# 4      18  شركت نوين چوب فاليز                           ...   33460968105
# 5      23  كيميا روكش گرگان                              ...   31649202645
# 6      13  شركت خزر كاسپين                               ...   29407055875
# 7      17  شركت ملامين سازه پويا                         ...   20473621510
# 8       3  سندل چوب                                      ...   17629202086
# 9      21  شركت پويا چوب                                 ...   16346298360
# 10      2  زاگرس چوب سام                                 ...   15731928319
# ...

# %% [markdown]
# ###  کل فروش شرکت

# %%
total_sale = vendor_sales['Net Amount'].sum()
total_sale
# Out:
# 730483914510

# %% [markdown]
# #### سهم هر یک از کل خرید شرکت

# %%
vendor_sale_share = (purchase.groupby('Vendor_Name' )['Net Amount'].sum()/ total_sale) * 100

# %%
vendor_sale_share_df = vendor_sale_share.reset_index()

vendor_sale_share_df.columns = ['Vendor_Name','Share_Total_Sales']
vendor_sale_share_df.head(3)
# Out:
#                                          Vendor_Name  Share_Total_Sales
# 0  اتحاديه سراسري درودگران                       ...           0.255953
# 1  خوش چسب كرمان                                 ...           0.635192
# 2  زاگرس چوب سام                                 ...           2.153631

# %%
vendor_sale_share_df.sort_values(ascending= False , by = 'Share_Total_Sales')
# Out:
#                                           Vendor_Name  Share_Total_Sales
# 14  شركت راش بينه                                 ...          25.813585
# 20  شركت پالار                                    ...          23.798218
# 11  شركت تخته فشرده شمال                          ...          14.126722
# 15  شركت روكش آريا پويا                           ...           5.009798
# 18  شركت نوين چوب فاليز                           ...           4.580658
# 23  كيميا روكش گرگان                              ...           4.332635
# 13  شركت خزر كاسپين                               ...           4.025695
# 17  شركت ملامين سازه پويا                         ...           2.802748
# 3   سندل چوب                                      ...           2.413359
# 21  شركت پويا چوب                                 ...           2.237736
# 2   زاگرس چوب سام                                 ...           2.153631
# 4   شركت آرين تخته                                ...           1.267004
# ...

# %%
top_vendors.to_excel('top_vendor.xlsx')
vendor_sale_share_df.to_excel('sale_share.xlsx')

# %%
top_vendor1 = pd.read_excel('top_vendor.xlsx')
sale_share1 = pd.read_excel('sale_share.xlsx')

# %%
top_vendor1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   26 non-null     int64
#  1   Vendor_Name  26 non-null     object
#  2   Net Amount   26 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 756.0+ bytes

# %%
top_vendor1.head()
top_vendor1 = top_vendor1.drop('Unnamed: 0' , axis=1)

# %%
top_vendor1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Vendor_Name  26 non-null     object
#  1   Net Amount   26 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 548.0+ bytes

# %%
merge_data = pd.merge( left = top_vendor1 ,
                        right= sale_share1 ,
                        on = 'Vendor_Name' , 
                        how = 'inner' , 
                        
                        )
merge_data
# Out:
#                                           Vendor_Name    Net Amount  \
# 0   شركت راش بينه                                 ...  188564083823
# 1   شركت پالار                                    ...  173842152375
# 2   شركت تخته فشرده شمال                          ...  103193429390
# 3   شركت روكش آريا پويا                           ...   36595766438
# 4   شركت نوين چوب فاليز                           ...   33460968105
# 5   كيميا روكش گرگان                              ...   31649202645
# 6   شركت خزر كاسپين                               ...   29407055875
# 7   شركت ملامين سازه پويا                         ...   20473621510
# 8   سندل چوب                                      ...   17629202086
# 9   شركت پويا چوب                                 ...   16346298360
# 10  زاگرس چوب سام                                 ...   15731928319
# 11  شركت آرين تخته                                ...    9255260369
# 12  شركت پارت چوب شاد                             ...    6203160240
# ...

# %%
merge_data = merge_data.drop('Unnamed: 0' , axis=1)

# %% [markdown]
# # سه تامین کننده با بیشترین میزان فروش و سهم هر یک از کل خرید شرکت

# %%
merge_data
# Out:
#                                           Vendor_Name    Net Amount  \
# 0   شركت راش بينه                                 ...  188564083823
# 1   شركت پالار                                    ...  173842152375
# 2   شركت تخته فشرده شمال                          ...  103193429390
# 3   شركت روكش آريا پويا                           ...   36595766438
# 4   شركت نوين چوب فاليز                           ...   33460968105
# 5   كيميا روكش گرگان                              ...   31649202645
# 6   شركت خزر كاسپين                               ...   29407055875
# 7   شركت ملامين سازه پويا                         ...   20473621510
# 8   سندل چوب                                      ...   17629202086
# 9   شركت پويا چوب                                 ...   16346298360
# 10  زاگرس چوب سام                                 ...   15731928319
# 11  شركت آرين تخته                                ...    9255260369
# 12  شركت پارت چوب شاد                             ...    6203160240
# ...

# %% [markdown]
# # برترین تامین کننده ها در هر ماه از سال

# %%
purchase.head()
# Out:
#        date  ID  Vendor_code  \
# 0  13990117   1      1100251
# 1  13990117   1      1100251
# 2  13990117   1      1100251
# 3  13990117   1      1100251
# 4  13990119   2      1100249
#
#                                          Vendor_Name             Item_Code  \
# 0  شركت تخته فشرده شمال                          ...  1-1-04-015
# 1  شركت تخته فشرده شمال                          ...  1-1-04-022
# 2  شركت تخته فشرده شمال                          ...  1-1-02-003
# 3  شركت تخته فشرده شمال                          ...  1-1-02-009
# 4  شركت پالار                                    ...  1-1-04-131
#
#                                          Description  \
# 0  ملامينه 204*260 كد 1 سفيد درجه A              ...
# 1  ملامينه 204*260 كد 78 آنتيك لايت درجه A       ...
# 2  زيرپالتي نئوپان 204*260                       ...
# 3  زيرپالتي ام دي اف 3ميل                        ...
# 4  ملامينه 210*366 كد 1 سفيد درجه A              ...
#
# ...

# %%
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2221 entries, 0 to 2231
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              2221 non-null   int64
#  1   ID                2221 non-null   int64
#  2   Vendor_code       2221 non-null   int64
#  3   Vendor_Name       2221 non-null   object
#  4   Item_Code         2221 non-null   object
#  5   Description       2221 non-null   object
#  6   Unit              2221 non-null   object
#  7   Quantity          2221 non-null   float64
#  8   Unit Price        2221 non-null   int64
#  9   Amount            2221 non-null   int64
#  10  Tax               2221 non-null   int64
#  11  Discount          2221 non-null   int64
#  12  Duties            2221 non-null   int64
#  13  Net Amount        2221 non-null   int64
#  14  Payment Date      2221 non-null   object
#  15  Warehouse Serial  2221 non-null   int64
# ...

# %%
wood = purchase.loc[: , ['Vendor_Name' , 'date' , 'Net Amount']].copy()

wood.head()
# Out:
#                                          Vendor_Name      date  Net Amount
# 0  شركت تخته فشرده شمال                          ...  13990117   645154650
# 1  شركت تخته فشرده شمال                          ...  13990117   102367350
# 2  شركت تخته فشرده شمال                          ...  13990117           0
# 3  شركت تخته فشرده شمال                          ...  13990117           0
# 4  شركت پالار                                    ...  13990119   408052400

# %%
wood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2221 entries, 0 to 2231
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Vendor_Name  2221 non-null   object
#  1   date         2221 non-null   int64
#  2   Net Amount   2221 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 69.4+ KB

# %%
import jdatetime as jdt
import jalali_pandas

# %%
def to_jalali_date(column, year_dir='L'): 
    if column.dtype == 'object':
        if '/' in column[0]:
            mod_col = [x.split('/') for x in column]
        elif '-' in column[0]:
            mod_col = [x.split('-') for x in column]
        elif '.' in column[0]:
            mod_col = [x.split('.') for x in column]
    
    elif column.dtype == 'int64':
        str_col = column.astype('str')
        if len(str(column[0])) == 8:
            if year_dir == 'L':
                mod_col = [[x[0:4], x[4:6], x[6:]] for x in str_col]
            elif year_dir == 'R':
                mod_col = [[x[0:2], x[2:4], x[4:]] for x in str_col]
        elif len(str(column[0])) == 6:
            mod_col = [[x[0:2], x[2:4], x[4:]] for x in str_col]

    if year_dir == 'L':
        year = [i[0] for i in mod_col]
        month = [i[1] for i in mod_col]
        day = [i[2] for i in mod_col]
    else:
        year = [i[2] for i in mod_col]
        month = [i[1] for i in mod_col]
        day = [i[0] for i in mod_col]

    if len(year[0]) == 2:
        if int(year[0]) < 50:
            year = ['14'+j for j in year]
        elif int(year[0]) > 50:
            year = ['13'+j for j in year]

    new_correct_date = []
    for n in range(len(year)):
        y = int(year[n])
        m = int(month[n])
        d = int(day[n])
        new_correct_date.append(jdt.date(y, m, d))  # jdt.datetime
    return new_correct_date

# %%
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2221 entries, 0 to 2231
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              2221 non-null   int64
#  1   ID                2221 non-null   int64
#  2   Vendor_code       2221 non-null   int64
#  3   Vendor_Name       2221 non-null   object
#  4   Item_Code         2221 non-null   object
#  5   Description       2221 non-null   object
#  6   Unit              2221 non-null   object
#  7   Quantity          2221 non-null   float64
#  8   Unit Price        2221 non-null   int64
#  9   Amount            2221 non-null   int64
#  10  Tax               2221 non-null   int64
#  11  Discount          2221 non-null   int64
#  12  Duties            2221 non-null   int64
#  13  Net Amount        2221 non-null   int64
#  14  Payment Date      2221 non-null   object
#  15  Warehouse Serial  2221 non-null   int64
# ...

# %%
wood['Inv_Date'] = to_jalali_date(wood['date'])
wood.sample(5)
# Out:
#                                             Vendor_Name      date  Net Amount  \
# 1785  شركت راش بينه                                 ...  13990929           0
# 1596  كيميا روكش گرگان                              ...  13990901           0
# 1112  شركت پالار                                    ...  13990702           0
# 2206  شركت پويا چوب                                 ...  13991228  1117764480
# 76    شركت نوين چوب فاليز                           ...  13990207           0
#
#         Inv_Date  year  month  day
# 1785  1399-09-29  1399      9   29
# 1596  1399-09-01  1399      9    1
# 1112  1399-07-02  1399      7    2
# 2206  1399-12-28  1399     12   28
# 76    1399-02-07  1399      2    7

# %%
wood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2221 entries, 0 to 2231
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Vendor_Name  2221 non-null   object
#  1   date         2221 non-null   int64
#  2   Net Amount   2221 non-null   int64
#  3   Inv_Date     2221 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 151.3+ KB

# %%
wood['year']    = wood.Inv_Date.jalali.year
wood['month']   = wood.Inv_Date.jalali.month
wood['day'] = wood.Inv_Date.jalali.day

wood.sample(5)
# Out:
#                                             Vendor_Name      date  Net Amount  \
# 1303  شركت ملامين سازه پويا                         ...  13990727    85142080
# 2186  شركت راش بينه                                 ...  13991225   906990247
# 1720  كيميا روكش گرگان                              ...  13990923  2531200093
# 2122  شركت روكش آريا پويا                           ...  13991212           0
# 47    شركت پالار                                    ...  13990202           0
#
#         Inv_Date  year  month  day
# 1303  1399-07-27  1399      7   27
# 2186  1399-12-25  1399     12   25
# 1720  1399-09-23  1399      9   23
# 2122  1399-12-12  1399     12   12
# 47    1399-02-02  1399      2    2

# %%
best_vendor = wood.groupby(
                            ['Vendor_Name' , 'year' , 'month']
                        
                            )['Net Amount'].sum().reset_index()

best_vendor.head(12)
# Out:
#                                           Vendor_Name  year  month  Net Amount
# 0   اتحاديه سراسري درودگران                       ...  1399      5  1869692861
# 1   خوش چسب كرمان                                 ...  1399      2   423104864
# 2   خوش چسب كرمان                                 ...  1399      3   521033167
# 3   خوش چسب كرمان                                 ...  1399      6   572897634
# 4   خوش چسب كرمان                                 ...  1399      7   609066276
# 5   خوش چسب كرمان                                 ...  1399     10   809510518
# 6   خوش چسب كرمان                                 ...  1399     11   825736912
# 7   خوش چسب كرمان                                 ...  1399     12   878625020
# 8   زاگرس چوب سام                                 ...  1399      1  1056515200
# 9   زاگرس چوب سام                                 ...  1399      2  2235110400
# 10  زاگرس چوب سام                                 ...  1399      3  1252854720
# ...

# %%
wood.groupby(['Vendor_Name' , 'year' , 'month'] ) .ngroups
# Out:
# 137

# %%
# .idxmx() _____ از برای پیدا کردن تأمین‌کننده‌ای که بالاترین فروش را در هر ماه دارد استفاده کنید.
top_vendor_month =best_vendor.loc[best_vendor.groupby( ['Vendor_Name' , 'year' , 'month'])['Net Amount'].idxmax()]
top_vendor_month
# Out:
#                                            Vendor_Name  year  month  \
# 0    اتحاديه سراسري درودگران                       ...  1399      5
# 1    خوش چسب كرمان                                 ...  1399      2
# 2    خوش چسب كرمان                                 ...  1399      3
# 3    خوش چسب كرمان                                 ...  1399      6
# 4    خوش چسب كرمان                                 ...  1399      7
# ..                                                 ...   ...    ...
# 132  كيميا روكش گرگان                              ...  1399     11
# 133  كيميا روكش گرگان                              ...  1399     12
# 134  يالماز اورمان(ياشار)                          ...  1399      3
# 135  گروه صنعتي بازرگاني خادم/ ولي اله رضايي(آوا)  ...  1399      3
# 136  گروه صنعتي بازرگاني خادم/ ولي اله رضايي(آوا)  ...  1399      4
#
#      Net Amount
# 0    1869692861
# 1     423104864
# 2     521033167
# 3     572897634
# 4     609066276
# ..          ...
# 132  2316000608
# ...

# %%
sort = top_vendor_month.sort_values( by= ['month' , 'Net Amount'] , ascending= [True , False])
sort.reset_index()
# Out:
#      index                                        Vendor_Name  year  month  \
# 0       66  شركت راش بينه                                 ...  1399      1
# 1      105  شركت پالار                                    ...  1399      1
# 2        8  زاگرس چوب سام                                 ...  1399      1
# 3      125  كيميا روكش گرگان                              ...  1399      1
# 4       41  شركت تخته فشرده شمال                          ...  1399      1
# ..     ...                                                ...   ...    ...
# 132    104  شركت پارت چوب شاد                             ...  1399     12
# 133     65  شركت خزر كاسپين                               ...  1399     12
# 134     36  شركت احسان كار اصفهان                         ...  1399     12
# 135     40  شركت تخته فشرده آريانا(پانيذ)                 ...  1399     12
# 136      7  خوش چسب كرمان                                 ...  1399     12
#
#       Net Amount
# 0    15657923478
# 1     5450475240
# ...

# %%
top_vendor_1_month = top_vendor_month.groupby(['year', 'month']).first().reset_index()
top_vendor_1_month
# Out:
#     year  month                                        Vendor_Name  Net Amount
# 0   1399      1  زاگرس چوب سام                                 ...  1056515200
# 1   1399      2  خوش چسب كرمان                                 ...   423104864
# 2   1399      3  خوش چسب كرمان                                 ...   521033167
# 3   1399      4  زاگرس چوب سام                                 ...  4848651360
# 4   1399      5  اتحاديه سراسري درودگران                       ...  1869692861
# 5   1399      6  خوش چسب كرمان                                 ...   572897634
# 6   1399      7  خوش چسب كرمان                                 ...   609066276
# 7   1399      8  زاگرس چوب سام                                 ...  1583910671
# 8   1399      9  سندل چوب                                      ...  1600000013
# 9   1399     10  خوش چسب كرمان                                 ...   809510518
# 10  1399     11  خوش چسب كرمان                                 ...   825736912
# ...
